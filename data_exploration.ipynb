# %% [markdown]
# <a href="https://colab.research.google.com/github/kennynlam/DATASCI-112-Final-Project/blob/main/DATASCI%20112%20Final%20Project%20(Data%20Exploration).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATASCI 112 Final Project - Data Exploration**

# %% [markdown]
# In this notebook, I read in the district data file and explore relationships between certain variables. Foremostly, I wanted to see if there was a correlation between population change and enrollment change (it would be somewhat logical to assume that a district's enrollment would increase if its county population increased). I also made sure to use rates instead of enrollment #s themselves (previous year enrollment & current year enrollment #s have a high correlation, but we cannot make any conclusions from that whatsoever).
#
# To visualize my findings, I attempted to use a variety of graphing methods such as choropleths, scatter plots, bar graphs, etc. I discuss the findings of these graphs in their respective cells.

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.9/dist-packages (0.12.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.4.4)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.9.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /usr/local/lib/python3.9/dist-packages (from geopandas) (3.4.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (6.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: munch>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# reading in the district data file
data_dir = "/content/gdrive/My Drive/Colab Notebooks/DATASCI 112/Final Project/Data Files/"
df_districts = pd.read_csv(data_dir + "df_districts.csv").set_index("District Name")
df_districts
# Out:
#                                            County Name  Rating Area  \
# District Name
# AGWSR Comm School District                      Hardin            1
# Alden Comm School District                      Hardin            1
# Eldora-New Providence Comm School District      Hardin            1
# Hubbard-Radcliffe Comm School District          Hardin            1
# Iowa Falls Comm School District                 Hardin            1
# ...                                                ...          ...
# Sibley-Ocheyedan Comm School District          Osceola            3
# South Hamilton Comm School District           Hamilton            1
# Stratford Comm School District                Hamilton            1
# Webster City Comm School District             Hamilton            1
# Van Buren County Comm School District        Van Buren            5
#
#                                             2019-20 Enrollment  \
# District Name
# AGWSR Comm School District                               670.0
# Alden Comm School District                               173.0
# Eldora-New Providence Comm School District               574.0
# Hubbard-Radcliffe Comm School District                   398.0
# Iowa Falls Comm School District                         1314.0
# ...                                                        ...
# Sibley-Ocheyedan Comm School District                    769.0
# South Hamilton Comm School District                      721.0
# Stratford Comm School District                            65.0
# Webster City Comm School District                       1904.0
# Van Buren County Comm School District                    842.0
#
#                                             2020-21 Enrollment  \
# District Name
# AGWSR Comm School District                               699.0
# Alden Comm School District                               169.0
# Eldora-New Providence Comm School District               529.0
# Hubbard-Radcliffe Comm School District                   413.0
# Iowa Falls Comm School District                         1249.0
# ...                                                        ...
# Sibley-Ocheyedan Comm School District                    766.0
# South Hamilton Comm School District                      688.0
# Stratford Comm School District                            64.0
# Webster City Comm School District                       1855.0
# Van Buren County Comm School District                    823.0
#
#                                             Previous 2 Year Enrollment Change  \
# District Name
# AGWSR Comm School District                                           0.029851
# Alden Comm School District                                           0.034682
# Eldora-New Providence Comm School District                          -0.097561
# Hubbard-Radcliffe Comm School District                              -0.057789
# Iowa Falls Comm School District                                     -0.029680
# ...                                                                       ...
# Sibley-Ocheyedan Comm School District                               -0.050715
# South Hamilton Comm School District                                 -0.030513
# Stratford Comm School District                                       0.015385
# Webster City Comm School District                                   -0.008929
# Van Buren County Comm School District                                0.011876
#
#                                             Previous Year Enrollment Change  \
# District Name
# AGWSR Comm School District                                        -0.012876
# Alden Comm School District                                         0.059172
# Eldora-New Providence Comm School District                        -0.020794
# Hubbard-Radcliffe Comm School District                            -0.092010
# Iowa Falls Comm School District                                    0.020817
# ...                                                                     ...
# Sibley-Ocheyedan Comm School District                             -0.046997
# South Hamilton Comm School District                                0.015988
# Stratford Comm School District                                     0.031250
# Webster City Comm School District                                  0.017251
# Van Buren County Comm School District                              0.035237
#
#                                             Previous 2 Year Population Change  \
# District Name
# AGWSR Comm School District                                          -0.008192
# Alden Comm School District                                          -0.008192
# Eldora-New Providence Comm School District                          -0.008192
# Hubbard-Radcliffe Comm School District                              -0.008192
# Iowa Falls Comm School District                                     -0.008192
# ...                                                                       ...
# Sibley-Ocheyedan Comm School District                                0.033736
# South Hamilton Comm School District                                  0.007717
# Stratford Comm School District                                       0.007717
# Webster City Comm School District                                    0.007717
# Van Buren County Comm School District                                0.028251
#
#                                             Previous Year Population Change  \
# District Name
# AGWSR Comm School District                                        -0.010072
# Alden Comm School District                                        -0.010072
# Eldora-New Providence Comm School District                        -0.010072
# Hubbard-Radcliffe Comm School District                            -0.010072
# Iowa Falls Comm School District                                   -0.010072
# ...                                                                     ...
# Sibley-Ocheyedan Comm School District                             -0.005329
# South Hamilton Comm School District                               -0.010107
# Stratford Comm School District                                    -0.010107
# Webster City Comm School District                                 -0.010107
# Van Buren County Comm School District                              0.005553
#
#                                             2021-22 Enrollment  Urban  ...  \
# District Name                                                          ...
# AGWSR Comm School District                               690.0  False  ...
# Alden Comm School District                               179.0  False  ...
# Eldora-New Providence Comm School District               518.0  False  ...
# Hubbard-Radcliffe Comm School District                   375.0  False  ...
# Iowa Falls Comm School District                         1275.0  False  ...
# ...                                                        ...    ...  ...
# Sibley-Ocheyedan Comm School District                    730.0  False  ...
# South Hamilton Comm School District                      699.0  False  ...
# Stratford Comm School District                            66.0  False  ...
# Webster City Comm School District                       1887.0  False  ...
# Van Buren County Comm School District                    852.0  False  ...
#
#                                             Percent ADA  \
# District Name
# AGWSR Comm School District                         92.1
# Alden Comm School District                         91.3
# Eldora-New Providence Comm School District         93.0
# Hubbard-Radcliffe Comm School District             92.8
# Iowa Falls Comm School District                    93.5
# ...                                                 ...
# Sibley-Ocheyedan Comm School District              94.5
# South Hamilton Comm School District                93.2
# Stratford Comm School District                     92.9
# Webster City Comm School District                  90.7
# Van Buren County Comm School District              92.9
#
#                                             Math Proficiency Rate  \
# District Name
# AGWSR Comm School District                               0.573171
# Alden Comm School District                               0.607595
# Eldora-New Providence Comm School District               0.650519
# Hubbard-Radcliffe Comm School District                   0.736434
# Iowa Falls Comm School District                          0.607692
# ...                                                           ...
# Sibley-Ocheyedan Comm School District                    0.703297
# South Hamilton Comm School District                      0.802784
# Stratford Comm School District                           0.846154
# Webster City Comm School District                        0.651613
# Van Buren County Comm School District                    0.624549
#
#                                             ELA Proficiency Rate  ISPP Index  \
# District Name
# AGWSR Comm School District                              0.678049   51.372500
# Alden Comm School District                              0.670886   56.190000
# Eldora-New Providence Comm School District              0.697917   53.070000
# Hubbard-Radcliffe Comm School District                  0.697674   53.635000
# Iowa Falls Comm School District                         0.762516   57.357500
# ...                                                          ...         ...
# Sibley-Ocheyedan Comm School District                   0.746137   51.450000
# South Hamilton Comm School District                     0.849188   61.995000
# Stratford Comm School District                          0.846154   54.440000
# Webster City Comm School District                       0.657143   55.118000
# Van Buren County Comm School District                   0.696751   53.913333
#
#                                             Percent Free/Reduced Price Lunch  \
# District Name
# AGWSR Comm School District                                            0.4311
# Alden Comm School District                                            0.4056
# Eldora-New Providence Comm School District                            0.4235
# Hubbard-Radcliffe Comm School District                                0.3983
# Iowa Falls Comm School District                                       0.3898
# ...                                                                      ...
# Sibley-Ocheyedan Comm School District                                 0.5130
# South Hamilton Comm School District                                   0.2395
# Stratford Comm School District                                        0.4528
# Webster City Comm School District                                     0.3769
# Van Buren County Comm School District                                 0.5031
#
#                                             Percent IEP  Percent EL  \
# District Name
# AGWSR Comm School District                     0.142029       0.011
# Alden Comm School District                     0.128492       0.049
# Eldora-New Providence Comm School District     0.173745       0.017
# Hubbard-Radcliffe Comm School District         0.133333       0.011
# Iowa Falls Comm School District                0.131765       0.031
# ...                                                 ...         ...
# Sibley-Ocheyedan Comm School District          0.126027       0.103
# South Hamilton Comm School District            0.092990       0.021
# Stratford Comm School District                 0.106061       0.000
# Webster City Comm School District              0.104928       0.147
# Van Buren County Comm School District          0.143192       0.000
#
#                                             2022-23 State Enrollment Projection  \
# District Name
# AGWSR Comm School District                                                702.0
# Alden Comm School District                                                279.0
# Eldora-New Providence Comm School District                                544.0
# Hubbard-Radcliffe Comm School District                                    447.0
# Iowa Falls Comm School District                                           984.0
# ...                                                                         ...
# Sibley-Ocheyedan Comm School District                                     716.0
# South Hamilton Comm School District                                       627.0
# Stratford Comm School District                                            126.0
# Webster City Comm School District                                        1762.0
# Van Buren County Comm School District                                     978.0
#
#                                             2022-23 Enrollment  \
# District Name
# AGWSR Comm School District                               650.0
# Alden Comm School District                               159.0
# Eldora-New Providence Comm School District               540.0
# Hubbard-Radcliffe Comm School District                   377.0
# Iowa Falls Comm School District                         1278.0
# ...                                                        ...
# Sibley-Ocheyedan Comm School District                    729.0
# South Hamilton Comm School District                      690.0
# Stratford Comm School District                            80.0
# Webster City Comm School District                       1827.0
# Van Buren County Comm School District                    867.0
#
#                                             Next Year Enrollment Change
# District Name
# AGWSR Comm School District                                    -0.057971
# Alden Comm School District                                    -0.111732
# Eldora-New Providence Comm School District                     0.042471
# Hubbard-Radcliffe Comm School District                         0.005333
# Iowa Falls Comm School District                                0.002353
# ...                                                                 ...
# Sibley-Ocheyedan Comm School District                         -0.001370
# South Hamilton Comm School District                           -0.012876
# Stratford Comm School District                                 0.212121
# Webster City Comm School District                             -0.031797
# Van Buren County Comm School District                          0.017606
#
# [327 rows x 25 columns]

# %%
df_districts.columns
# Out:
# Index(['County Name', 'Rating Area', '2019-20 Enrollment',
#        '2020-21 Enrollment', 'Previous 2 Year Enrollment Change',
#        'Previous Year Enrollment Change', 'Previous 2 Year Population Change',
#        'Previous Year Population Change', '2021-22 Enrollment', 'Urban',
#        'Percent White', 'Percent Hispanic', 'Percent Asian', 'Percent Black',
#        'Percent Multi-Race', 'Percent ADA', 'Math Proficiency Rate',
#        'ELA Proficiency Rate', 'ISPP Index',
#        'Percent Free/Reduced Price Lunch', 'Percent IEP', 'Percent EL',
#        '2022-23 State Enrollment Projection', '2022-23 Enrollment',
#        'Next Year Enrollment Change'],
#       dtype='object')

# %% [markdown]
# # **Choropleths**

# %%
import geopandas as gpd

# %%
# reading in a shapefile of Iowa rating area boundaries
gdf_ra = gpd.read_file(data_dir + "Rating Areas SF.zip")
gdf_ra.rename(columns={"ratingarea": "Rating Area"}, inplace=True)
for i in range(len(gdf_ra["Rating Area"])):
  gdf_ra.loc[i, "Rating Area"] = gdf_ra.loc[i, "Rating Area"][12]
gdf_ra["Rating Area"] = gdf_ra["Rating Area"].astype(int)
gdf_ra
# Out:
#    Rating Area                                           counties  centroidx  \
# 0            1  Boone, Calhoun, Carroll, Greene, Grundy, Hamil...     -93.60
# 1            2  Dallas, Jasper, Madison, Marion, Polk, and Warren     -93.54
# 2            3  Buena Vista, Cherokee, Clay, Crawford, Dickins...     -95.58
# 3            4  Adair, Adams, Audubon, Cass, Clarke, Decatur, ...     -94.91
# 4            5  Appanoose, Davis, Des Moines, Henry, Jefferson...     -92.16
# 5            6  Benton, Black Hawk, Buchanan, Cedar, Clayton, ...     -91.37
# 6            7  Allamakee, Bremer, Butler, Cerro Gordo, Chicka...     -92.99
#
#    centroidy                                           geometry
# 0      42.16  POLYGON ((-94.42287 42.64525, -94.40308 42.645...
# 1      41.52  POLYGON ((-94.18348 41.86351, -94.16427 41.863...
# 2      42.75  POLYGON ((-95.15114 43.50105, -95.13223 43.500...
# 3      41.18  POLYGON ((-96.00180 41.86362, -95.98273 41.863...
# 4      41.03  POLYGON ((-91.34747 41.59836, -91.34658 41.598...
# 5      42.15  POLYGON ((-91.56844 43.08179, -91.54873 43.081...
# 6      43.08  POLYGON ((-94.75827 43.50105, -94.75055 43.501...

# %%
# building a function to graph features by rating area
def make_ra_choropleth(feature, c):
  # creating a df with a feature's average by rating area
  df = pd.DataFrame(df_districts.groupby("Rating Area")[feature].mean())
  gdf_ra_feature = gdf_ra.merge(df, on="Rating Area", how="outer")
  # standardizing a specific legend range for changes in enrollment
  if feature == "Next Year Enrollment Change" or feature == "Previous Year Enrollment Change":
    gdf_ra_feature.to_crs("NAD1983").plot(
    column=feature,
    legend=True,
    figsize=(10, 10),
    cmap=c,
    vmax=.03, vmin=-.03)
  else:
    gdf_ra_feature.to_crs("NAD1983").plot(
    column=feature,
    legend=True,
    figsize=(10, 10),
    cmap=c)

# %%
# Choropleth of Average Changes in Enrollment from 2020-21 to 2021-22 by Rating Area
make_ra_choropleth("Previous Year Enrollment Change", "RdBu")
# Central rating area experienced the greatest increase in enrollment from 2020-21 to 2021-22

# %%
# Choropleth of Average Changes in Enrollment from 2021-22 to 2022-23 by Rating Area
make_ra_choropleth("Next Year Enrollment Change", "RdBu")
# 3 out of 7 rating areas maintained average increases in enrollment from 2020-21 to 2022-23 (2 years)

# %%
# Choropleth of Average Percentages of White Students by Rating Area
make_ra_choropleth("Percent White", "Oranges")
# Northwest & Central rating areas have the lowest average % of white students

# %%
# Choropleth of Average ELA Proficiency Rates by Rating Area
make_ra_choropleth("ELA Proficiency Rate", "Oranges")
# Northwest & Central rating areas have the highest average ELA proficiency rates

# %%
# afterward, I decided to explore the data at a smaller, county-level scale
# reading in a shapefile of Iowa county boundaries
gdf_counties = gpd.read_file(data_dir + "Iowa_County_Boundaries")
gdf_counties.rename(columns={"CountyName": "County Name"}, inplace=True)
gdf_counties["County Name"].replace("Obrien", "O'Brien", inplace=True)
gdf_counties
# Out:
#     OBJECTID  PERIMETER  DOMCountyI   FIPS  FIPS_INT County Name StateAbbr  \
# 0          1   193975.5          60  19119     19119        Lyon        IA
# 1          2   130929.6          72  19143     19143     Osceola        IA
# 2          3   131290.5          30  19059     19059   Dickinson        IA
# 3          4   130956.8          32  19063     19063       Emmet        IA
# 4          5   172890.3           3  19005     19005   Allamakee        IA
# ..       ...        ...         ...    ...       ...         ...       ...
# 94        95   144995.3          26  19051     19051       Davis        IA
# 95        96   148600.8          27  19053     19053     Decatur        IA
# 96        97   147785.1          93  19185     19185       Wayne        IA
# 97        98   146566.5           4  19007     19007   Appanoose        IA
# 98        99   192783.7          56  19111     19111         Lee        IA
#
#     SHAPE_Leng  SHAPE_Area                                           geometry
# 0     2.212753    0.169102  POLYGON ((-96.59915 43.50033, -96.58647 43.500...
# 1     1.434543    0.114867  POLYGON ((-95.86089 43.49998, -95.84104 43.499...
# 2     1.438023    0.116176  POLYGON ((-95.38781 43.50024, -95.37542 43.500...
# 3     1.434046    0.115803  POLYGON ((-94.91476 43.50087, -94.89795 43.500...
# 4     1.847862    0.189376  POLYGON ((-91.61075 43.50060, -91.61061 43.500...
# ..         ...         ...                                                ...
# 94    1.526090    0.139393  POLYGON ((-92.63926 40.89896, -92.62026 40.898...
# 95    1.558094    0.147367  POLYGON ((-94.01480 40.89705, -93.99519 40.896...
# 96    1.551256    0.145582  POLYGON ((-93.55648 40.89838, -93.53804 40.898...
# 97    1.540049    0.142517  POLYGON ((-93.09759 40.89823, -93.07897 40.898...
# 98    2.029479    0.148545  POLYGON ((-91.71876 40.81362, -91.69951 40.813...
#
# [99 rows x 10 columns]

# %%
# building a function to graph features by county
def make_county_choropleth(feature, c):
  # creating a df with a feature's average by county
  df = pd.DataFrame(df_districts.groupby("County Name")[feature].mean())
  gdf_counties_feature = gdf_counties.merge(df, on="County Name", how="outer")
  # standardizing a specific legend range for changes in enrollment
  if feature == "Next Year Enrollment Change" or feature == "Previous Year Enrollment Change":
    gdf_counties_feature.to_crs("NAD1983").plot(
      column=feature,
      legend=True,
      figsize=(10, 10),
      cmap=c,
      vmax=.06, vmin=-.06)
  else:
    gdf_counties_feature.to_crs("NAD1983").plot(
      column=feature,
      legend=True,
      figsize=(10, 10),
      cmap=c)

# %%
# Choropleth of Average Changes in Enrollment from 2020-21 to 2021-22 by County
make_county_choropleth("Previous Year Enrollment Change", "RdBu")

# %%
# Choropleth of Average Changes in Enrollment from 2021-22 to 2022-23 by County
make_county_choropleth("Next Year Enrollment Change", "RdBu")
# unable to identify a specific trend in enrollment from 2020-21 to 2022-23 (some counties maintained average increases/decreases while others flip-flopped)

# %%
# Choropleth of Average 2021-22 ADA Rates by County
make_county_choropleth("Percent ADA", "Greens")

# %%
# Choropleth of Average 2021-22 ISPP Indexes by County
make_county_choropleth("ISPP Index", "Purples")
# ADA & ISPP index choropleths slightly overlap at the county level (not enough to make a definitive conclusion)

# %% [markdown]
# # **Scatterplots**

# %%
# computing a correlation matrix between 2020-21 to 2021-22 enrollment change and corresponding population change
df_districts[["Previous Year Enrollment Change", "Previous Year Population Change"]].corr()
# relatively weak correlation between enrollment change and population change
# Out:
#                                  Previous Year Enrollment Change  \
# Previous Year Enrollment Change                         1.000000
# Previous Year Population Change                         0.172706
#
#                                  Previous Year Population Change
# Previous Year Enrollment Change                         0.172706
# Previous Year Population Change                         1.000000

# %%
# verifying this conclusion through a scatterplot
df_districts.plot.scatter(x="Previous Year Enrollment Change", y="Previous Year Population Change")
# Out:
# <Axes: xlabel='Previous Year Enrollment Change', ylabel='Previous Year Population Change'>

# %%
# computing a correlation matrix between previous year enrollment change and next year enrollment change
df_districts[["Previous Year Enrollment Change", "Next Year Enrollment Change"]].corr()
# relatively weak correlation between the 2 variables (a previous year increase in enrollment does not imply a next year increase/decrease & vice versa)
# Out:
#                                  Previous Year Enrollment Change  \
# Previous Year Enrollment Change                         1.000000
# Next Year Enrollment Change                             0.072268
#
#                                  Next Year Enrollment Change
# Previous Year Enrollment Change                     0.072268
# Next Year Enrollment Change                         1.000000

# %%
# verifying this conclusion through a scatterplot
df_districts.plot.scatter(x="Previous Year Enrollment Change", y="Next Year Enrollment Change")
# Out:
# <Axes: xlabel='Previous Year Enrollment Change', ylabel='Next Year Enrollment Change'>

# %%
# Scatterplot of Math Proficiency Rates vs. ADA Rates
df_districts.plot.scatter(x="Math Proficiency Rate", y="Percent ADA")
# somewhat positive correlation between the 2 variables (greater ADA rate may correspond w/ a greater math proficiency rate)
# Out:
# <Axes: xlabel='Math Proficiency Rate', ylabel='Percent ADA'>

# %%
# Scatterplot of FRPL Rates vs. ADA Rates
df_districts.plot.scatter(x="Percent Free/Reduced Price Lunch", y="Percent ADA")
# somewhat negative correlation between the 2 variables (greater FRPL rate may correspond w/ a lower ADA rate)
# Out:
# <Axes: xlabel='Percent Free/Reduced Price Lunch', ylabel='Percent ADA'>

# %%
# Scatterplot of IEP Rates vs. ADA Rates
df_districts.plot.scatter(x="Percent IEP", y="Percent ADA")
# slightly negative correlation between the 2 variables (greater IEP rate may correspond w/ a lower ADA rate)
# Out:
# <Axes: xlabel='Percent IEP', ylabel='Percent ADA'>

# %%
df_districts.corr()["Next Year Enrollment Change"]
# overall, the variable "Next Year Enrollment Change" has extremely weak correlation values w/ other singular variables
# suggests that a greater number of variables may be necessary to build a better prediction model
# Out:
# Rating Area                            0.001790
# 2019-20 Enrollment                    -0.009846
# 2020-21 Enrollment                    -0.003779
# Previous 2 Year Enrollment Change      0.257224
# Previous Year Enrollment Change        0.072268
# Previous 2 Year Population Change      0.099085
# Previous Year Population Change        0.122191
# 2021-22 Enrollment                    -0.002007
# Urban                                 -0.051373
# Percent White                          0.035503
# Percent Hispanic                      -0.030134
# Percent Asian                          0.010291
# Percent Black                         -0.040634
# Percent Multi-Race                    -0.013784
# Percent ADA                            0.104483
# Math Proficiency Rate                  0.082335
# ELA Proficiency Rate                   0.104016
# ISPP Index                             0.092451
# Percent Free/Reduced Price Lunch      -0.153853
# Percent IEP                           -0.158125
# Percent EL                            -0.027683
# 2022-23 State Enrollment Projection   -0.006249
# 2022-23 Enrollment                     0.007818
# Next Year Enrollment Change            1.000000
# Name: Next Year Enrollment Change, dtype: float64

# %% [markdown]
# # **Bar Graphs**

# %%
# using qcut to create categorical variables of quantitative variables w/ even distribution
df_districts["District Size"] = pd.qcut(df_districts["2021-22 Enrollment"], q=4) # splitting district enrollments into 4 categories by size
df_districts["ISPP Index Category"] = pd.qcut(df_districts["ISPP Index"], q=4) # splitting ispp indexes into 4 categories by value

# %%
# Bar Graph of Average Next Year Enrollment Changes by District Size
df_districts.groupby("District Size")["Next Year Enrollment Change"].mean().plot.bar(ylabel="Average Next Year Enrollment Change")
# larger districts experienced greater average increases in 2021-22 to 2022-23 enrollment than smaller districts (difference is admittedly very small)
# Out:
# <Axes: xlabel='District Size', ylabel='Average Next Year Enrollment Change'>

# %%
# Bar Graph of Average Previous Year Enrollment Changes by District Size
df_districts.groupby("District Size")["Previous Year Enrollment Change"].mean().plot.bar(ylabel="Average Previous Year Enrollment Change")
# largest districts experienced the greatest average increase in 2020-21 to 2021-22 enrollment
# Out:
# <Axes: xlabel='District Size', ylabel='Average Previous Year Enrollment Change'>

# %%
# Bar Graph of Average Next Year Enrollment Changes by ISPP Index Category
df_districts.groupby("ISPP Index Category")["Next Year Enrollment Change"].mean().plot.bar(ylabel="Average Next Year Enrollment Change")
# districts w/ greater ISPP indexes experienced greater average increases in 2021-22 to 2022-23 enrollment than smaller districts (difference is admittedly very small)
# Out:
# <Axes: xlabel='ISPP Index Category', ylabel='Average Next Year Enrollment Change'>

# %%
# Bar Graph of Average Next Year Enrollment Changes by Urban/non-Urban Status
df_districts.groupby("Urban")["Next Year Enrollment Change"].mean().plot.bar(ylabel="Average Next Year Enrollment Change")
# urban districts experienced an average decrease in 2021-22 to 2022-23 enrollment, while non-urban districts experienced an average increase in enrollment
# Out:
# <Axes: xlabel='Urban', ylabel='Average Next Year Enrollment Change'>

# %%
# Bar Graph of Average Math Proficiency Rates by Urban/non-Urban Status
df_districts.groupby("Urban")["Math Proficiency Rate"].mean().plot.bar(ylabel="Average Math Proficiency Rate")
# non-urban districts have a greater average math proficiency rate than urban districts
# Out:
# <Axes: xlabel='Urban', ylabel='Average Math Proficiency Rate'>
